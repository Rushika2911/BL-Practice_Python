# %% [markdown]
# Program1:OOPS Banner
# oops- it provides the structure to depict real world scenarios
# objects are the attributes that define the object
# methods are the ones that manipulate the data
# Real world entities-
# - noun can be the class and object
# - actions can be the methods

# %%
print('   ***   ',' ',' ','   ***   ',' ',' ','****** ',' ',' ','***** ')
print(' **   ** ',' ',' ',' **   ** ',' ',' ','**   **',' ',' ','**    ')
print('**     **',' ',' ','**     **',' ',' ','**   **',' ',' ','**    ')
print('**     **',' ',' ','**     **',' ',' ','**   **',' ',' ','**    ')
print('**     **',' ',' ','**     **',' ',' ','****** ',' ',' ',' ***  ')
print('**     **',' ',' ','**     **',' ',' ','**     ',' ',' ','   ** ')
print('**     **',' ',' ','**     **',' ',' ','**     ',' ',' ','    **')
print(' **   ** ',' ',' ',' **   ** ',' ',' ','**     ',' ',' ','   ** ')
print('   ***   ',' ',' ','   ***   ',' ',' ','**     ',' ',' ','***** ')
# Out:
#    ***           ***        ******      *****
#  **   **       **   **      **   **     **
# **     **     **     **     **   **     **
# **     **     **     **     **   **     **
# **     **     **     **     ******       ***
# **     **     **     **     **             **
# **     **     **     **     **              **
#  **   **       **   **      **             **
#    ***           ***        **          *****

# %% [markdown]
# Program2: Places to visit
# input() function :
# - it is a built-in function whihc is overridden
# - instead of reading from standard keyboard buffer, the program interacts with an HTML input element, which is abstracted to function as the standard input.
#
# f-strings:
# - f-strings are a way to format strings in Python, introduced in Python 3.6
# - it is literal for string and looks for anything in {} and replace it with the value of the variable or expression inside the braces.
# - f string supports single, double, triple quotes. different quote styles help avoid syntax error
# - using {} is a must and no undefined varibales should be used

# %%
name= input("enter your name: ")
first_place= input(" first place: ")
sec_place= input("second place: ")
third_place= input("third place: ")
year= input("which year: ")
print(f"hello my name is {name} and places i visited are {first_place}, {sec_place} and {third_place}\n"+
      f"in the year {year}")
# Out:
# hello my name is rushika and places i visited are chandigarh, goa and otty
# in the year 2024

# %% [markdown]
# Program3: Compute Circumference and Area of Circle
# Data Types: Python uses basic data types (such as float, int, bool, and string), which are all implemented as classes and objects. While Python implicitly assigns data types to variables, explicit type conversion is often necessary—for example, converting input from a string to a float using the float() function.
#
# Constants: it is good practice to define constants in uppercase letters on top of the program in global scope
#
# Operator Precedence (PEMDAS): When executing expressions, Python follows the order of operations: Parentheses, Exponents, Multiplication and Division (left to right), and Addition and Subtraction (left to right). Parentheses are used to override default precedence and ensure specific parts of an expression are evaluated first.
#
# to improve readability, we use :.2f to print output upto 2 decimal places

# %%
PI= 22/7
radius= float(input("enter the radius of the circle: "))
circumference= 2*PI*radius
area= PI*(radius **2)
print(f"circumfernce of the circle is {circumference:.2f}")
print(f"area of the circle is {area:.2f}")
# Out:
# circumfernce of the circle is 31.43
# area of the circle is 78.57

# %% [markdown]
# Program 4: Find Generation
#
# Operators:
# - Arithmetic operators: +,-,*,/,//,%,**
# - Logical operators: and, or, not
# - Relational or comparison operators: ==, !=, >, <, >=, <= . they return boolean values True or False. == is used to check equality ie. checks value of variable. is operator is used to check identity ie. checks memory location of variable that if both are pointed to same object in the memory or not
# - Assigment operators: =, +=, -=, *=, /=, //=, **=, %=. they are used to assign values to variables. += is used to add and assign the value to the variable. it is equivalent to a= a+b. similarly for other operators

# %%
year = int(input("Enter your birth year: "))

if 1946 < year <= 1964:
    generation = "Boomer"
elif 1965 <= year <= 1980:
    generation = "Generation X"
elif 1981 <= year <= 1996:
    generation = "Millennials"
elif 1997 <= year <= 2012:
    generation = "Generation Z"
elif 2013 <= year <= 2025:
    generation = "Generation Alpha"
else:
    generation = "Invalid birth year"

print(f"Birth year is: {year}")
print(f"Your generation is: {generation}")
# Out:
# Birth year is: 2005
# Your generation is: Generation Z

# %% [markdown]
# Program 5: Time Conversion

# %%
seconds = int(input("Enter Number of Seconds: "))

hours = seconds // 3600
minutes = (seconds % 3600) // 60
sec = seconds % 60

print(f"Time duration of {seconds} seconds in HH:MM:SS format is {hours:02d}:{minutes:02d}:{sec:02d}")
# Out:
# Time duration of 234567 seconds in HH:MM:SS format is 65:09:27

# %% [markdown]
# Program 6: Bill Generation App

# %%
APPLE_GST = 0.12
ORANGE_GST = 0.05
buyer_name = input("Enter Buyer Name: ")

apple_price_kg = int(input("Enter Apple price per kg: "))
apple_quantity_kg = float(input("Enter Apple Quantity in kg: "))

orange_price_kg = int(input("Enter Orange price per kg: "))
orange_quantity_kg = float(input("Enter Orange Quantity in kg: "))

total_price_apple = apple_price_kg * apple_quantity_kg
total_price_orange = orange_price_kg * orange_quantity_kg

total_gst_apple = total_price_apple * APPLE_GST
total_gst_orange = total_price_orange * ORANGE_GST

total_billing_apple = total_price_apple + total_gst_apple
total_billing_orange = total_price_orange + total_gst_orange

grand_total = total_billing_apple + total_billing_orange

total_amount = total_billing_apple + total_billing_orange
total_round_amount = round(total_amount)

# Print the bill

print(f"\nBuyer Name: {buyer_name}")
print(f"{'-' * 74}")

print(
    f"| {'Item Code':^10} | {'Price/Unit':^10} | {'# unit':^5} | "
    f"{'Price':^5} | {'GST':^10} | {'Total w/ GST':^10} |"
)
print(f"{'-' * 74}")
print(
    f"| {'Apple':^10} | {'Rs ' + str(apple_price_kg):^10} | {apple_quantity_kg:^5} | "
    f"{'Rs ' + str(total_price_apple):^5} | {'Rs ' + str(total_gst_apple):^10} | "
    f"{'Rs ' + str(total_billing_apple):^10} |")
print(
    f"| {'Orange':^10} | {'Rs ' + str(orange_price_kg):^10} | {orange_quantity_kg:^5} | "
    f"{'Rs ' + str(total_price_orange):^5} | {'Rs ' + str(total_gst_orange):^10} | "
    f"{'Rs ' + str(total_billing_orange):^10} |")
print(f"{'-' * 74}")
print(f"Total {' ' * 54}\u20B9 {total_amount:.2f}")
print(f"Total Round {' ' * 48}\u20B9 {total_round_amount:.2f}")
print(f"{'-' * 74}")

# %% [markdown]
# Program 7:  School Report App
# CODIN STEPS
# Step 1: - Specifying Constants for School, Class, subjects marks, total, and number of students
# Step 2: - Get student name, physics, chemistry and maths marks for Student 1 and Calculate total marks for student 1
# Step 3: - Calculating physics, chemistry and maths percentage for student 1
# Step 4: - Print results for student 1
# Step 5: - Get student name, physics, chemistry and maths marks for Student 2 and Calculate total marks for student 2
# Step 6: - Calculating physics, chemistry and maths percentage for student 2
# Step 7: - Print results for student 2
# Step 8: - Get student name, physics, chemistry and maths marks for Student 3 and Calculate total marks for student 3
# Step 9: - Calculating physics, chemistry and maths percentage for student 3
# Step 10: - Print results for student 3
# Step 11: - Calculate total marks obtained by all students in each subject
# Step 12: - Calculate class averages for each subject
# Step 13: - Calculate the class average percentage for each subject
# Step 14: - Calculate total marks obtained by all students
# Step 15: - Calculate overall percentage
# Step 16: - Print the class average percentage for each subject

# %%
#Step 1: - Specifying Constants for School, Class, subjects marks, total, and number of students
SCHOOL_NAME= "New School Of Learning"
CLASS_NAME = "Class XI"
TOTAL_SUBJECT_MARKS = 50
TOTAL_MARKS = TOTAL_SUBJECT_MARKS * 3
NUMBER_STUDENTS = 3

#Step 2: - Get student name, physics, chemistry and maths marks for Student 1 and Calculate total marks for student 1
student1= input("enter name of student 1: ")
student1_phy_marks= int(input("enter physics marks out of 50 for student 1: "))
student1_chem_marks= int(input("enter chemistry marks out of 50 for student 1: "))
student1_math_marks= int(input("enetr mathematics marks out of 50 for student 1: "))
total_student1_marks= student1_phy_marks+ student1_math_marks+student1_chem_marks

#Step 3: - Calculating physics, chemistry and maths percentage for student 1
student1_phys_perc= round((student1_phy_marks/TOTAL_SUBJECT_MARKS)*100,2)
student1_chem_perc= round((student1_chem_marks/TOTAL_SUBJECT_MARKS)*100,2)
student1_maths_perc= round((student1_math_marks/TOTAL_SUBJECT_MARKS)*100,2)

#Step 4: - Print results for student 1

print(f"\n{SCHOOL_NAME} - {CLASS_NAME} - {student1}")
print(f"{'-' * 72}")
print(f"| {'Subject':^15} | {'Total Marks':^15} | {'Marks Obtained':^15} | {'Percentage':^15} |")
print(f"{'-' * 72}")
print(f"| {'Physics':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student1_phy_marks:^15}",f"| {student1_phys_perc:^15} |")
print(f"| {'Chemistry':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student1_chem_marks:^15}",f"| {student1_chem_perc:^15} |")
print(f"| {'Mathematics':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student1_math_marks:^15}",f"| {student1_maths_perc:^15} |")
print(f"{'-' * 72}")
print(f"| {'Total':^15} | {TOTAL_MARKS:^15} | {total_student1_marks:^15}",f"| {round((total_student1_marks / TOTAL_MARKS) * 100, 2):^15} |")
print(f"{'-' * 72}\n\n")

# Step 5: Get input and calculate total marks for student 2

student2 = input("Enter name of student 2: ")
student2_phys_marks = int(input("Enter Physics marks out of 50 for student 2: "))
student2_chem_marks = int(input("Enter Chemistry marks out of 50 for student 2: "))
student2_math_marks = int(input("Enter Mathematics marks out of 50 for student 2: "))

total_student2_marks = (student2_phys_marks+ student2_chem_marks+ student2_math_marks)

# Step 6: Calculating subject wise percentage for student 2

student2_phys_perc = round((student2_phys_marks / TOTAL_SUBJECT_MARKS) * 100, 2)
student2_chem_perc = round((student2_chem_marks / TOTAL_SUBJECT_MARKS) * 100, 2)
student2_math_perc = round((student2_math_marks / TOTAL_SUBJECT_MARKS) * 100, 2)

#Step 7: - Print results for student 2

print(f"\n{SCHOOL_NAME} - {CLASS_NAME} - {student2}")
print(f"{'-' * 72}")
print(f"| {'Subject':^15} | {'Total Marks':^15} | {'Marks Obtained':^15} | {'Percentage':^15} |")
print(f"{'-' * 72}")
print(f"| {'Physics':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student2_phys_marks:^15}",f"| {student2_phys_perc:^15} |")
print(f"| {'Chemistry':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student2_chem_marks:^15}",f"| {student2_chem_perc:^15} |")
print(f"| {'Mathematics':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student2_math_marks:^15}",f"| {student2_math_perc:^15} |")
print(f"{'-' * 72}")
print(f"| {'Total':^15} | {TOTAL_MARKS:^15} | {total_student2_marks:^15}",f"| {round((total_student2_marks / TOTAL_MARKS) * 100, 2):^15} |")
print(f"{'-' * 72}\n\n")

# Step 8: Get input and calculate total marks for student 3

student3 = input("Enter name of student 3: ")
student3_phys_marks = int(input("Enter Physics marks out of 50 for student 3: "))
student3_chem_marks = int(input("Enter Chemistry marks out of 50 for student 3: "))
student3_math_marks = int(input("Enter Mathematics marks out of 50 for student 3: "))

total_student3_marks = (student3_phys_marks+ student3_chem_marks+ student3_math_marks)

# Step 9: Calculating subject wise percentage for student 3

student3_phys_perc = round((student3_phys_marks / TOTAL_SUBJECT_MARKS) * 100, 2)
student3_chem_perc = round((student3_chem_marks / TOTAL_SUBJECT_MARKS) * 100, 2)
student3_math_perc = round((student3_math_marks / TOTAL_SUBJECT_MARKS) * 100, 2)

#Step 10: - Print results for student 3

print(f"\n{SCHOOL_NAME} - {CLASS_NAME} - {student2}")
print(f"{'-' * 72}")
print(f"| {'Subject':^15} | {'Total Marks':^15} | {'Marks Obtained':^15} | {'Percentage':^15} |")
print(f"{'-' * 72}")
print(f"| {'Physics':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student3_phys_marks:^15}",f"| {student3_phys_perc:^15} |")
print(f"| {'Chemistry':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student3_chem_marks:^15}",f"| {student3_chem_perc:^15} |")
print(f"| {'Mathematics':^15} | {TOTAL_SUBJECT_MARKS:^15} | {student3_math_marks:^15}",f"| {student3_math_perc:^15} |")
print(f"{'-' * 72}")
print(f"| {'Total':^15} | {TOTAL_MARKS:^15} | {total_student3_marks:^15}",f"| {round((total_student3_marks / TOTAL_MARKS) * 100, 2):^15} |")
print(f"{'-' * 72}\n\n")

# Step 11: Calculate total marks obtained by all students in each subject

total_phys_marks = student1_phy_marks + student2_phys_marks + student3_phys_marks
total_chem_marks = student1_chem_marks + student2_chem_marks + student3_chem_marks
total_math_marks = student1_math_marks + student2_math_marks + student3_math_marks

# Step 12: Calculate class averages for each subject

class_phys_avg = total_phys_marks / NUMBER_STUDENTS
class_chem_avg = total_chem_marks / NUMBER_STUDENTS
class_math_avg = total_math_marks / NUMBER_STUDENTS

# Step 13: Calculate the class average percentage for each subject

class_phys_perc = (class_phys_avg / TOTAL_SUBJECT_MARKS) * 100
class_chem_perc = (class_chem_avg / TOTAL_SUBJECT_MARKS) * 100
class_math_perc = (class_math_avg / TOTAL_SUBJECT_MARKS) * 100

# Step 14: Calculate total marks obtained by all students

total_student_marks = total_student1_marks + total_student2_marks + total_student3_marks

# Step 15: Calculate overall percentage

overall_perc = (total_student_marks / (NUMBER_STUDENTS * TOTAL_MARKS)) * 100


# Step 16: Print the class average percentage for each subject

print("\nClass Average And Percentage for Each Subject:")

print(f"Physics Average is {class_phys_avg:.2f} and Percentage is {class_phys_perc:.2f}%")

print(f"Chemistry Average is {class_chem_avg:.2f} and Percentage is {class_chem_perc:.2f}%")

print(f"Mathematics Average is {class_math_avg:.2f} and Percentage is {class_math_perc:.2f}%")

print(f"Overall Percentage: {overall_perc:.2f}%")
# Out:
# New School Of Learning - Class XI - rushika
# ------------------------------------------------------------------------
# |     Subject     |   Total Marks   | Marks Obtained  |   Percentage    |
# ------------------------------------------------------------------------
# |     Physics     |       50        |       49        |      98.0       |
# |    Chemistry    |       50        |       49        |      98.0       |
# |   Mathematics   |       50        |       50        |      100.0      |
# ------------------------------------------------------------------------
# |      Total      |       150       |       148       |      98.67      |
# ------------------------------------------------------------------------
#
#
#
# New School Of Learning - Class XI - somya
# ------------------------------------------------------------------------
# |     Subject     |   Total Marks   | Marks Obtained  |   Percentage    |
# ...

# %% [markdown]
# Python Standard IO Programs

# %%
#Program 4
name= input("enter friend's name: ")
city= input("City: ")
print(f"Name of my friend is {name} and his/her place of stay is {city}")
# Out:
# Name of my friend is somya and his/her place of stay is mumbai

# %%
#Program 8
# Program: Retail Shop Billing System

# Step 1: GST Constants
HOUSEHOLD_GST = 0.05
PROCESSED_FOOD_GST = 0.12

# Step 2: Get Buyer Details

buyer_name = input("Enter Buyer Name: ")

household_price = int(input("Enter Household Good Price: "))
household_qty = float(input("Enter Household Good Quantity: "))

processed_price = int(input("Enter Processed Food Price: "))
processed_qty = float(input("Enter Processed Food Quantity: "))

# Step 3: Calculate Total Price

household_total = household_price * household_qty
processed_total = processed_price * processed_qty

# Step 4: Calculate GST

household_gst = household_total * HOUSEHOLD_GST
processed_gst = processed_total * PROCESSED_FOOD_GST

# Step 5: Calculate Total with GST

household_bill = household_total + household_gst
processed_bill = processed_total + processed_gst

# Step 6: Calculate Grand Total

total_amount = household_bill + processed_bill
rounded_total = round(total_amount)

# Step 7: Print Bill

print(f"\nBuyer Name: {buyer_name}")
print("-" * 82)
print(f"| {'Item Code':^18} | {'Price/Unit':^10} | {'#unit':^5} | {'Price':^10} | {'GST':^10} | {'Total w/ GST':^12} |")
print("-" * 82)
print(f"| {'Household Good':^18} | {'Rs ' + str(household_price):^10} | {household_qty:^5} | " f"{'Rs ' + str(household_total):^10} | {'Rs ' + str(household_gst):^10} | "f"{'Rs ' + str(household_bill):^12} |")
print(f"| {'Processed Food':^18} | {'Rs ' + str(processed_price):^10} | {processed_qty:^5} | "f"{'Rs ' + str(processed_total):^10} | {'Rs ' + str(processed_gst):^10} | "f"{'Rs ' + str(processed_bill):^12} |")
print("-" * 82)
print(f"Total{' ' * 63}\u20B9 {total_amount:.2f}")
print(f"Total Round{' ' * 57}\u20B9 {rounded_total:.2f}")
print("-" * 82)
# Out:
# Buyer Name: rushika
# ----------------------------------------------------------------------------------
# |     Item Code      | Price/Unit | #unit |   Price    |    GST     | Total w/ GST |
# ----------------------------------------------------------------------------------
# |   Household Good   |   Rs 350   |  5.0  | Rs 1750.0  |  Rs 87.5   |  Rs 1837.5   |
# |   Processed Food   |   Rs 125   | 10.0  | Rs 1250.0  |  Rs 150.0  |  Rs 1400.0   |
# ----------------------------------------------------------------------------------
# Total                                                               ₹ 3237.50
# Total Round                                                         ₹ 3238.00
# ----------------------------------------------------------------------------------
